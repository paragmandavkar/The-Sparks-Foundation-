# %% [markdown]
# Task 3-Data Science & business Analytics
#
# By Parag Mandavkar intern at The Sparks Foundation
#
# Task-Perform EDA on samplesuperstore Dataset

# %% [markdown]
# Step 1 : Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Step 2 : Read Dataset

# %%
df = pd.read_csv('SampleSuperstore (1).csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.T.head(10)
# Out:
#                        0              1                2                3     \
# Ship Mode      Second Class   Second Class     Second Class   Standard Class
# Segment            Consumer       Consumer        Corporate         Consumer
# Country       United States  United States    United States    United States
# City              Henderson      Henderson      Los Angeles  Fort Lauderdale
# State              Kentucky       Kentucky       California          Florida
# Postal Code           42420          42420            90036            33311
# Region                South          South             West            South
# Category          Furniture      Furniture  Office Supplies        Furniture
# Sub-Category      Bookcases         Chairs           Labels           Tables
# Sales                261.96         731.94            14.62         957.5775
#
#                          4               5                6     \
# Ship Mode      Standard Class  Standard Class   Standard Class
# Segment              Consumer        Consumer         Consumer
# Country         United States   United States    United States
# City          Fort Lauderdale     Los Angeles      Los Angeles
# State                 Florida      California       California
# Postal Code             33311           90032            90032
# Region                  South            West             West
# Category      Office Supplies       Furniture  Office Supplies
# Sub-Category          Storage     Furnishings              Art
# Sales                  22.368           48.86             7.28
#
#                         7                8                9     ...  \
# Ship Mode     Standard Class   Standard Class   Standard Class  ...
# Segment             Consumer         Consumer         Consumer  ...
# Country        United States    United States    United States  ...
# City             Los Angeles      Los Angeles      Los Angeles  ...
# State             California       California       California  ...
# Postal Code            90032            90032            90032  ...
# Region                  West             West             West  ...
# Category          Technology  Office Supplies  Office Supplies  ...
# Sub-Category          Phones          Binders       Appliances  ...
# Sales                907.152           18.504            114.9  ...
#
#                          9984             9985            9986  \
# Ship Mode      Standard Class   Standard Class  Standard Class
# Segment              Consumer         Consumer        Consumer
# Country         United States    United States   United States
# City               Long Beach       Long Beach     Los Angeles
# State                New York         New York      California
# Postal Code             11561            11561           90008
# Region                   East             East            West
# Category      Office Supplies  Office Supplies      Technology
# Sub-Category           Labels         Supplies     Accessories
# Sales                    31.5             55.6           36.24
#
#                         9987            9988           9989            9990  \
# Ship Mode     Standard Class  Standard Class   Second Class  Standard Class
# Segment            Corporate       Corporate       Consumer        Consumer
# Country        United States   United States  United States   United States
# City                  Athens          Athens          Miami      Costa Mesa
# State                Georgia         Georgia        Florida      California
# Postal Code            30605           30605          33180           92627
# Region                 South           South          South            West
# Category          Technology      Technology      Furniture       Furniture
# Sub-Category     Accessories          Phones    Furnishings     Furnishings
# Sales                  79.99           206.1         25.248           91.96
#
#                         9991             9992             9993
# Ship Mode     Standard Class   Standard Class     Second Class
# Segment             Consumer         Consumer         Consumer
# Country        United States    United States    United States
# City              Costa Mesa       Costa Mesa      Westminster
# State             California       California       California
# Postal Code            92627            92627            92683
# Region                  West             West             West
# Category          Technology  Office Supplies  Office Supplies
# Sub-Category          Phones            Paper       Appliances
# Sales                258.576             29.6           243.16
#
# [10 rows x 9994 columns]

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.size
# Out:
# 129922

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %% [markdown]
# step 3 : Check duplicate values

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# Drop the Duplicate values

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %% [markdown]
# Step 4 : Min,max,median & mode

# %%
df.min()
# Out:
# Ship Mode         First Class
# Segment              Consumer
# Country         United States
# City                 Aberdeen
# State                 Alabama
# Postal Code              1040
# Region                Central
# Category            Furniture
# Sub-Category      Accessories
# Sales                   0.444
# Quantity                    1
# Discount                  0.0
# Profit              -6599.978
# dtype: object

# %%
df.max()
# Out:
# Ship Mode       Standard Class
# Segment            Home Office
# Country          United States
# City                      Yuma
# State                  Wyoming
# Postal Code              99301
# Region                    West
# Category            Technology
# Sub-Category            Tables
# Sales                 22638.48
# Quantity                    14
# Discount                   0.8
# Profit                8399.976
# dtype: object

# %%
df.median()
# Out:
# Postal Code    56430.5000
# Sales             54.4900
# Quantity           3.0000
# Discount           0.2000
# Profit             8.6665
# dtype: float64

# %%
df.mode()
# Out:
#         Ship Mode   Segment        Country           City       State  \
# 0  Standard Class  Consumer  United States  New York City  California
#
#    Postal Code Region         Category Sub-Category  Sales  Quantity  \
# 0        10035   West  Office Supplies      Binders  12.96         3
#
#    Discount  Profit
# 0       0.0     0.0

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df['City'].head(15)
# Out:
# 0           Henderson
# 1           Henderson
# 2         Los Angeles
# 3     Fort Lauderdale
# 4     Fort Lauderdale
# 5         Los Angeles
# 6         Los Angeles
# 7         Los Angeles
# 8         Los Angeles
# 9         Los Angeles
# 10        Los Angeles
# 11        Los Angeles
# 12            Concord
# 13            Seattle
# 14         Fort Worth
# Name: City, dtype: object

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Pensacola          1
# Manhattan          1
# Lake Elsinore      1
# Rogers             1
# Goldsboro          1
# Name: City, Length: 531, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# South Carolina            42
# Louisiana                 42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %% [markdown]
# Using iloc

# %%
df.iloc[0:5]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.iloc[[0,3,5]]
# Out:
#         Ship Mode   Segment        Country             City       State  \
# 0    Second Class  Consumer  United States        Henderson    Kentucky
# 3  Standard Class  Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class  Consumer  United States      Los Angeles  California
#
#    Postal Code Region   Category Sub-Category     Sales  Quantity  Discount  \
# 0        42420  South  Furniture    Bookcases  261.9600         2      0.00
# 3        33311  South  Furniture       Tables  957.5775         5      0.45
# 5        90032   West  Furniture  Furnishings   48.8600         7      0.00
#
#      Profit
# 0   41.9136
# 3 -383.0310
# 5   14.1694

# %%
df.iloc[1:10,:4]
# Out:
#         Ship Mode    Segment        Country             City
# 1    Second Class   Consumer  United States        Henderson
# 2    Second Class  Corporate  United States      Los Angeles
# 3  Standard Class   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Consumer  United States  Fort Lauderdale
# 5  Standard Class   Consumer  United States      Los Angeles
# 6  Standard Class   Consumer  United States      Los Angeles
# 7  Standard Class   Consumer  United States      Los Angeles
# 8  Standard Class   Consumer  United States      Los Angeles
# 9  Standard Class   Consumer  United States      Los Angeles

# %% [markdown]
# Matplotlib & Seaborn

# %%
df.hist(figsize=(20,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df)

# %%
df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Category')
plt.pie(df['Category'].value_counts(), labels=df['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
# computing top categories in term of sales from first 100 observation
top_category_s = df.groupby("Category").Sales.sum().nlargest(n=100)

# computing top categories in term of profit from 100 observation
top_category_p = df.groupby("Category").Profit.sum().nlargest(n=100)

#plotting to see 
plt.style.use('seaborn')
top_category_s.plot(kind = 'bar',figsize =(10,5),fontsize =14)
top_category_p.plot(kind = 'bar',figsize =(10,5),fontsize =14,color='red')
plt.xlabel('Category',fontsize = 15)
plt.ylabel('Total category Sales vs Profit',fontsize = 15)
plt.title("Top category sales vs profit",fontsize = 15)
plt.show()

# %%
plt.figure(figsize= (10,16))
df.groupby('Category')['Profit','Sales'].agg([sum]).plot.bar()
plt.ylabel('Profit')
plt.show()
# Out:
# <ipython-input-38-a55ba0fe09d8>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Category')['Profit','Sales'].agg([sum]).plot.bar()

# %%
plt.figure(figsize=(14,12))
statwise = df.groupby(['Sub-Category'])['Profit'].sum().nlargest(20)
statwise.plot.barh()
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %%
plt.figure(figsize=(8,7))
sns.lineplot(df['Discount'], df['Profit'])
# Out:
# C:\Users\parag\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
plt.figure(figsize = (6,6))
plt.title('Region')
plt.pie(df['Region'].value_counts(), labels=df['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
plt.style.use('seaborn')
df.plot(kind = "scatter",figsize = (10,5), x = "Sales" , y="Profit", c ="Discount", s= 20,fontsize = 16,colormap = "cividis_r")
plt.ylabel("Total Profits",fontsize = 16)
plt.title("Interdependency of sale,Profits and Discounts",fontsize =16)
plt.show()

# %%
# computing top states in terms of sales from first 10 observations
top_states_s = df.groupby("State").Sales.sum().nlargest(n=10)

# computing top states in terms of profit from first 10 observations
top_states_p = df.groupby("State").Profit.sum().nlargest(n = 10)

plt.style.use('seaborn')
top_states_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_states_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales',fontsize = 15)
plt.title("Top 10 states Sales vs Profit",fontsize = 15)
plt.show()
